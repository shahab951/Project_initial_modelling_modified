# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv('C:/Users/shaha/Desktop/Springboard/Unit11_Project/Cleaned_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0         hotel  is_canceled  lead_time  arrival_date_year  \
# 0           0  Resort Hotel            0        342               2015
# 1           1  Resort Hotel            0        737               2015
# 2           2  Resort Hotel            0          7               2015
# 3           3  Resort Hotel            0         13               2015
# 4           4  Resort Hotel            0         14               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  ...  assigned_room_type  \
# ...

# %%
df.select_dtypes('object')
# Out:
#                hotel arrival_date_month meal country market_segment  \
# 0       Resort Hotel               July   BB     PRT         Direct
# 1       Resort Hotel               July   BB     PRT         Direct
# 2       Resort Hotel               July   BB     GBR         Direct
# 3       Resort Hotel               July   BB     GBR      Corporate
# 4       Resort Hotel               July   BB     GBR      Online TA
# ...              ...                ...  ...     ...            ...
# 118897    City Hotel             August   BB     BEL  Offline TA/TO
# 118898    City Hotel             August   BB     FRA      Online TA
# 118899    City Hotel             August   BB     DEU      Online TA
# 118900    City Hotel             August   BB     GBR      Online TA
# 118901    City Hotel             August   HB     DEU      Online TA
#
#        distribution_channel reserved_room_type assigned_room_type  \
# 0                    Direct                  C                  C
# ...

# %%
#Checking the number of categorical variables for each column
print('Hotel type')
print(df['hotel'].value_counts())
print('-----------------------------')
print('arrival_date_month')
print(df['arrival_date_month'].value_counts())
print('-----------------------------')
print('Meal')
print(df['meal'].value_counts())
print('-----------------------------')
print('Country')
print(df['country'].value_counts())
print('-----------------------------')
print('Market_segment')
print(df['market_segment'].value_counts())
print('-----------------------------')
print('Distribution_channel')
print(df['distribution_channel'].value_counts())
print('-----------------------------')
print('Reserved_room_type')
print(df['reserved_room_type'].value_counts())
print('-----------------------------')
print('Assigned_room_type')
print(df['assigned_room_type'].value_counts())
print('-----------------------------')
print('Deposit_type')
print(df['deposit_type'].value_counts())
print('-----------------------------')
print('Customer_type')
print(df['customer_type'].value_counts())
print('-----------------------------')
print('Reservation_status')
print(df['reservation_status'].value_counts())
print('-----------------------------')
# Out:
# Hotel type
# City Hotel      79306
# Resort Hotel    39596
# Name: hotel, dtype: int64
# -----------------------------
# arrival_date_month
# August       13856
# July         12628
# May          11779
# October      11095
# April        11045
# June         10927
# September    10467
# March         9739
# February      8012
# November      6752
# December      6728
# January       5874
# Name: arrival_date_month, dtype: int64
# -----------------------------
# Meal
# BB           91867
# HB           14434
# SC           10638
# Undefined     1165
# FB             798
# Name: meal, dtype: int64
# -----------------------------
# Country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64
# -----------------------------
# Market_segment
# Online TA        56403
# Offline TA/TO    24160
# Groups           19806
# ...

# %%
#checking undefined values of market_segment in the dataframe
df[df['market_segment']=='Undefined']
# Out:
#        Unnamed: 0       hotel  is_canceled  lead_time  arrival_date_year  \
# 40136       40600  City Hotel            1          2               2015
# 40215       40679  City Hotel            1          1               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 40136             August                        32                          3
# 40215             August                        32                          5
#
#        stays_in_weekend_nights  stays_in_week_nights  ...  assigned_room_type  \
# 40136                        1                     0  ...                   B
# 40215                        0                     2  ...                   B
#
#        booking_changes  deposit_type days_in_waiting_list    customer_type  \
# 40136                0    No Deposit                    0  Transient-Party
# 40215                0    No Deposit                    0  Transient-Party
#
# ...

# %%
#checking undefined values of distribtuion_channel in the dataframe
df[df['distribution_channel']=='Undefined']
# Out:
#        Unnamed: 0         hotel  is_canceled  lead_time  arrival_date_year  \
# 14185       14594  Resort Hotel            0        103               2015
# 40136       40600    City Hotel            1          2               2015
# 40203       40667    City Hotel            1          1               2015
# 40215       40679    City Hotel            1          1               2015
# 40696       41160    City Hotel            1          8               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 14185               July                        28                          5
# 40136             August                        32                          3
# 40203             August                        32                          5
# 40215             August                        32                          5
# 40696             August                        33                         13
#
# ...

# %%
#Second step of cleaning, removing undefined values
df=df.drop(index=df[df['market_segment']=='Undefined'].index)
df=df.drop(index=df[df['distribution_channel']=='Undefined'].index)
df=df.drop(columns=['Unnamed: 0'], axis=1)

# %%
print('Market_segment')
print(df['market_segment'].value_counts())
print('-----------------------------')
print('Distribution_channel')
print(df['distribution_channel'].value_counts())
print('-----------------------------')
# Out:
# Market_segment
# Online TA        56402
# Offline TA/TO    24160
# Groups           19806
# Direct           12447
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64
# -----------------------------
# Distribution_channel
# TA/TO        97730
# Direct       14483
# Corporate     6491
# GDS            193
# Name: distribution_channel, dtype: int64
# -----------------------------

# %%
df.shape
# Out:
# (118897, 30)

# %%
#Saving the dataset to a csv file
df.to_csv('C:/Users/shaha/Desktop/Springboard/Unit11_Project/Cleaned_data II.csv')

# %%
dfi=df.drop(['meal','reservation_status','reservation_status_date'],axis=1)

# %%
#Generating dummy variables
df_dummy=pd.get_dummies(dfi, columns=['hotel','arrival_date_month','country','market_segment','distribution_channel','reserved_room_type','assigned_room_type','deposit_type','customer_type'], prefix='C')

# %%
df_dummy.head(10)
# Out:
#    is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0            0        342               2015                        27
# 1            0        737               2015                        27
# 2            0          7               2015                        27
# 3            0         13               2015                        27
# 4            0         14               2015                        27
# 5            0         14               2015                        27
# 6            0          0               2015                        27
# 7            0          9               2015                        27
# 8            1         85               2015                        27
# 9            1         75               2015                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# ...

# %%
df_dummy.shape
# Out:
# (118897, 249)

# %%
#Scaling and modelling
dfm=df_dummy
X=dfm.drop(['is_canceled'], axis=1).values
y=dfm['is_canceled'].values
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.3, random_state=21)
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)
knn_scaled=KNeighborsClassifier(n_neighbors=5)
knn_scaled.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# In my idea, the columns of 'is_canceled', 'meal' and 'reservation_status' can be dependent variables for prediction. The modeling for 'is_canceled' has been performed. So the next step can be modelling for prediction of 'meal' and 'reservation_status'
